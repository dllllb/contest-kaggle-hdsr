# %%
import pandas as pd
stats = pd.read_json('results.json').sort_values('rmse-mean')
stats.T[stats.nunique() > 1].T
# Out:
#    colsample_bytree est_type exec-time-sec rmse-mean    rmse-std subsample  \
# 12              0.6      xgb       2385.82  0.472303   0.0111595       0.6
# 6               0.7      xgb       2155.62  0.474708   0.0129298       0.7
# 9               0.7      xgb       1032.77  0.491105  0.00663381       0.7
# 4               0.7      xgb       1017.98  0.495558   0.0087562       0.7
# 10              0.6      xgb       345.628  0.498106  0.00859122       0.6
# 8               0.7      xgb       329.776   0.49817  0.00804649       0.7
# 7               0.7      xgb       673.607  0.511427  0.00848039       0.7
# 3               0.7      xgb       969.823   0.51217    0.012786       0.7
# 2               0.7      xgb       4414.66  0.513853    0.014901       0.7
# 11              0.7      xgb       221.979  0.514115  0.00339353       0.7
# 0               0.7      xgb       5424.42  0.524247   0.0133953       0.7
# ...
